# %% [markdown]
# # **1- Importing required libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import missingno as msno
from wordcloud import WordCloud

sns.set(style="darkgrid")

# %% [markdown]
# # **2- Reading data**

# %%
store_data = pd.read_csv("/content/drive/MyDrive/For Colab/SampleSuperstore.csv")

# %%
store_data.head()
# Out:
#         Ship Mode    Segment        Country  ... Quantity Discount    Profit
# 0    Second Class   Consumer  United States  ...        2     0.00   41.9136
# 1    Second Class   Consumer  United States  ...        3     0.00  219.5820
# 2    Second Class  Corporate  United States  ...        2     0.00    6.8714
# 3  Standard Class   Consumer  United States  ...        5     0.45 -383.0310
# 4  Standard Class   Consumer  United States  ...        2     0.20    2.5164
#
# [5 rows x 13 columns]

# %% [markdown]
# # **3- Checking meta information of dataframe**

# %%
store_data.shape
# Out:
# (9994, 13)

# %%
store_data.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %% [markdown]
# ## **4- Checking statistical information of dataframe**

# %%
store_data.describe()[["Sales","Quantity", 'Discount', 'Profit']].T.style.bar(subset=['mean'], color='#205ff2')\
                                                .background_gradient(subset=['std'], cmap='Reds')\
                                                .background_gradient(subset=['50%'], cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 100.0%, transparent 100.0%);
#         }#T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row0_col2{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }#T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row0_col5{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row1_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 1.6%, transparent 1.6%);
#         }#T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row1_col2,#T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row2_col2{
#             background-color:  #fff5f0;
#             color:  #000000;
#         }#T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row1_col5{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row2_col1{
#             width:  10em;
#              height:  80%;
#         }#T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row2_col5{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row3_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 12.4%, transparent 12.4%);
#         }#T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row3_col2{
#             background-color:  #fc9272;
#             color:  #000000;
#         }#T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row3_col5{
#             background-color:  #6b8df0;
#             color:  #000000;
#         }</style><table id="T_9841de1e_ff37_11eb_bfe4_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >mean</th>        <th class="col_heading level0 col2" >std</th>        <th class="col_heading level0 col3" >min</th>        <th class="col_heading level0 col4" >25%</th>        <th class="col_heading level0 col5" >50%</th>        <th class="col_heading level0 col6" >75%</th>        <th class="col_heading level0 col7" >max</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9841de1e_ff37_11eb_bfe4_0242ac1c0002level0_row0" class="row_heading level0 row0" >Sales</th>
#                         <td id="T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row0_col0" class="data row0 col0" >9994.000000</td>
#                         <td id="T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row0_col1" class="data row0 col1" >229.858001</td>
#                         <td id="T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row0_col2" class="data row0 col2" >623.245101</td>
#                         <td id="T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row0_col3" class="data row0 col3" >0.444000</td>
#                         <td id="T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row0_col4" class="data row0 col4" >17.280000</td>
#                         <td id="T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row0_col5" class="data row0 col5" >54.490000</td>
#                         <td id="T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row0_col6" class="data row0 col6" >209.940000</td>
#                         <td id="T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row0_col7" class="data row0 col7" >22638.480000</td>
#             </tr>
#             <tr>
#                         <th id="T_9841de1e_ff37_11eb_bfe4_0242ac1c0002level0_row1" class="row_heading level0 row1" >Quantity</th>
#                         <td id="T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row1_col0" class="data row1 col0" >9994.000000</td>
#                         <td id="T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row1_col1" class="data row1 col1" >3.789574</td>
#                         <td id="T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row1_col2" class="data row1 col2" >2.225110</td>
#                         <td id="T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row1_col3" class="data row1 col3" >1.000000</td>
#                         <td id="T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row1_col4" class="data row1 col4" >2.000000</td>
#                         <td id="T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row1_col5" class="data row1 col5" >3.000000</td>
#                         <td id="T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row1_col6" class="data row1 col6" >5.000000</td>
#                         <td id="T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row1_col7" class="data row1 col7" >14.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_9841de1e_ff37_11eb_bfe4_0242ac1c0002level0_row2" class="row_heading level0 row2" >Discount</th>
#                         <td id="T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row2_col0" class="data row2 col0" >9994.000000</td>
#                         <td id="T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row2_col1" class="data row2 col1" >0.156203</td>
#                         <td id="T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row2_col2" class="data row2 col2" >0.206452</td>
#                         <td id="T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row2_col3" class="data row2 col3" >0.000000</td>
#                         <td id="T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row2_col4" class="data row2 col4" >0.000000</td>
#                         <td id="T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row2_col5" class="data row2 col5" >0.200000</td>
#                         <td id="T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row2_col6" class="data row2 col6" >0.200000</td>
#                         <td id="T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row2_col7" class="data row2 col7" >0.800000</td>
#             </tr>
#             <tr>
#                         <th id="T_9841de1e_ff37_11eb_bfe4_0242ac1c0002level0_row3" class="row_heading level0 row3" >Profit</th>
#                         <td id="T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row3_col0" class="data row3 col0" >9994.000000</td>
#                         <td id="T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row3_col1" class="data row3 col1" >28.656896</td>
#                         <td id="T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row3_col2" class="data row3 col2" >234.260108</td>
#                         <td id="T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row3_col3" class="data row3 col3" >-6599.978000</td>
#                         <td id="T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row3_col4" class="data row3 col4" >1.728750</td>
#                         <td id="T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row3_col5" class="data row3 col5" >8.666500</td>
#                         <td id="T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row3_col6" class="data row3 col6" >29.364000</td>
#                         <td id="T_9841de1e_ff37_11eb_bfe4_0242ac1c0002row3_col7" class="data row3 col7" >8399.976000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## **5- Checking for NaN values**

# %%
msno.bar(store_data, color='b', figsize = (12,6));

# %% [markdown]
# **So none of the column contains NaN value**

# %% [markdown]
# # **6- Visualization**

# %%
store_data['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
px.histogram(store_data,
             x = "Ship Mode",
             color='Segment',
             title = "<b>Counts in Ship Mode</b>",)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="2b12beb8-b5f0-492c-9ebd-9260f9f03de4" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("2b12beb8-b5f0-492c-9ebd-9260f9f03de4")) {
#                     Plotly.newPlot(
#                         '2b12beb8-b5f0-492c-9ebd-9260f9f03de4',
#                         [{"alignmentgroup": "True", "bingroup": "x", "hoverlabel": {"namelength": 0}, "hovertemplate": "Segment=Consumer<br>Ship Mode=%{x}<br>count=%{y}", "legendgroup": "Segment=Consumer", "marker": {"color": "#636efa"}, "name": "Segment=Consumer", "offsetgroup": "Segment=Consumer", "orientation": "v", "showlegend": true, "type": "histogram", "x": ["Second Class", "Second Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Second Class", "Second Class", "Second Class", "Second Class", "Second Class", "Standard Class", "Second Class", "Second Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Second Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "First Class", "First Class", "First Class", "First Class", "First Class", "First Class", "First Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "First Class", "Standard Class", "Second Class", "Standard Class", "Standard Class", "Standard Class", "Second Class", "Standard Class", "Standard Class", "Second Class", "Standard Class", "Standard Class", "Second Class", "Second Class", "Second Class", "First Class", "Second Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Second Class", "Second Class", "Second Class", "Second Class", "Standard Class", "First Class", "First Class", "First Class", "First Class", "First Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Second Class", "Standard Class", "Standard Class", "First Class", "Second Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Second Class", "Second Class", "Second Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "First Class", "First Class", "Second Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "First Class", "First Class", "First Class", "First Class", "First Class", "First Class", "Standard Class", "Standard Class", "Second Class", "Second Class", "Second Class", "Second Class", "Second Class", "Second Class", "Second Class", "Second Class", "Standard Class", "Standard Class", "First Class", "First Class", "Second Class", "Second Class", "Second Class", "Standard Class", "Standard Class", "Standard Class", "First Class", "First Class", "First Class", "Second Class", "Second Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "First Class", "First Class", "First Class", "First Class", "First Class", "First Class", "Second Class", "Second Class", "Second Class", "Second Class", "Second Class", "Second Class", "Second Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "Standard Class", "First Class", "Standard Class", "Standard Class", "Second Class", "Second Class", "Second Class", "Second Class", "Second Class", "Second Class", "First Class", "Standard Cl ...

# %% [markdown]
# **Above histogram shows that Ship Mode has 4 categories and Standard Class has more counts then others. Also In Standard Class more Segmants belongs to Consumer class then Corporate and then Home Office**

# %% [markdown]
# ## **6.1- Analyze Segment**

# %%
store_data['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
fig = px.pie(store_data, names = "Segment",
             title = "<b>Counts in Segment</b>",
             hole = 0.5)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="33ed8a77-a9c3-43f0-9cf0-43d58ce673a5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("33ed8a77-a9c3-43f0-9cf0-43d58ce673a5")) {
#                     Plotly.newPlot(
#                         '33ed8a77-a9c3-43f0-9cf0-43d58ce673a5',
#                         [{"domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hole": 0.5, "hoverlabel": {"namelength": 0}, "hovertemplate": "Segment=%{label}", "labels": ["Consumer", "Consumer", "Corporate", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Home Office", "Home Office", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Corporate", "Corporate", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Home Office", "Corporate", "Corporate", "Home Office", "Home Office", "Home Office", "Home Office", "Corporate", "Corporate", "Corporate", "Corporate", "Corporate", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Corporate", "Corporate", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Home Office", "Corporate", "Corporate", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Corporate", "Corporate", "Corporate", "Consumer", "Corporate", "Corporate", "Consumer", "Consumer", "Corporate", "Home Office", "Consumer", "Consumer", "Consumer", "Home Office", "Corporate", "Corporate", "Corporate", "Consumer", "Consumer", "Consumer", "Home Office", "Home Office", "Consumer", "Corporate", "Home Office", "Home Office", "Home Office", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Home Office", "Corporate", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Corporate", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Home Office", "Consumer", "Consumer", "Consumer", "Home Office", "Home Office", "Corporate", "Corporate", "Corporate", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Corporate", "Corporate", "Corporate", "Corporate", "Consumer", "Consumer", "Home Office", "Corporate", "Corporate", "Corporate", "Corporate", "Home Office", "Home Office", "Corporate", "Corporate", "Corporate", "Home Office", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Corporate", "Corporate", "Consumer", "Consumer", "Consumer", "Home Office", "Corporate", "Corporate", "Home Office", "Home Office", "Home Office", "Consumer", "Home Office", "Corporate", "Corporate", "Home Office", "Home Office", "Home Office", "Home Office", "Home Office", "Corporate", "Consumer", "Consumer", "Home Office", "Corporate", "Corporate", "Consumer", "Consumer", "Consumer", "Consumer", "Corporate", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Corporate", "Corporate", "Corporate", "Corporate", "Corporate", "Corporate", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Corporate", "Corporate", "Corporate", "Consumer", "Consumer", "Corporate", "Home Office", "Home Office", "Home Office", "Home Office", "Home Office", "Corporate", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Home Office", "Home Office", "Home Office", "Home Office", "Home Office", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Corporate", "Corporate", "Corporate", "Corporate", "Consumer", "Consumer", "Consumer", "Corporate", "Corporate", "Corporate", "Consumer", "Consumer", "Corporate", "Consumer", "Corporate", "Corporate", "Corporate", "Consumer", "Consumer", "Consumer", "Corporate", "Corporate", "Corporate", "Corporate", "Corporate", "Corporate", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Consumer", "Corporate", "Corporate", "Corporate", "Home Office", "Home Office", "Home Office", "Home Office", "Corporate", "Corporate", "Corporate", "Corporate", "Corporate", "Corporate", "Corporate", "C ...

# %% [markdown]
# ## **6.2- Analyzing which product Sub-category has more profit**

# %%
prod_wise = store_data[["Sub-Category", "Profit"]].groupby(['Sub-Category'],
                                                      as_index=False).sum().sort_values(by='Profit',
                                                                                        ascending=False)


px.bar(data_frame = prod_wise, x = "Sub-Category", y = "Profit",
       color="Sub-Category",
       title = "<b>Product Category Vs Profit</b>")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="8f30d7b2-3d3d-49fa-9735-449f29ea2a45" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("8f30d7b2-3d3d-49fa-9735-449f29ea2a45")) {
#                     Plotly.newPlot(
#                         '8f30d7b2-3d3d-49fa-9735-449f29ea2a45',
#                         [{"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Sub-Category=%{x}<br>Profit=%{y}", "legendgroup": "Sub-Category=Copiers", "marker": {"color": "#636efa"}, "name": "Sub-Category=Copiers", "offsetgroup": "Sub-Category=Copiers", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Copiers"], "xaxis": "x", "y": [55617.82490000001], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Sub-Category=%{x}<br>Profit=%{y}", "legendgroup": "Sub-Category=Phones", "marker": {"color": "#EF553B"}, "name": "Sub-Category=Phones", "offsetgroup": "Sub-Category=Phones", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Phones"], "xaxis": "x", "y": [44515.7306], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Sub-Category=%{x}<br>Profit=%{y}", "legendgroup": "Sub-Category=Accessories", "marker": {"color": "#00cc96"}, "name": "Sub-Category=Accessories", "offsetgroup": "Sub-Category=Accessories", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Accessories"], "xaxis": "x", "y": [41936.63569999993], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Sub-Category=%{x}<br>Profit=%{y}", "legendgroup": "Sub-Category=Paper", "marker": {"color": "#ab63fa"}, "name": "Sub-Category=Paper", "offsetgroup": "Sub-Category=Paper", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Paper"], "xaxis": "x", "y": [34053.56929999997], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Sub-Category=%{x}<br>Profit=%{y}", "legendgroup": "Sub-Category=Binders", "marker": {"color": "#FFA15A"}, "name": "Sub-Category=Binders", "offsetgroup": "Sub-Category=Binders", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Binders"], "xaxis": "x", "y": [30221.763299999995], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Sub-Category=%{x}<br>Profit=%{y}", "legendgroup": "Sub-Category=Chairs", "marker": {"color": "#19d3f3"}, "name": "Sub-Category=Chairs", "offsetgroup": "Sub-Category=Chairs", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Chairs"], "xaxis": "x", "y": [26590.166300000026], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Sub-Category=%{x}<br>Profit=%{y}", "legendgroup": "Sub-Category=Storage", "marker": {"color": "#FF6692"}, "name": "Sub-Category=Storage", "offsetgroup": "Sub-Category=Storage", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Storage"], "xaxis": "x", "y": [21278.826399999998], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Sub-Category=%{x}<br>Profit=%{y}", "legendgroup": "Sub-Category=Appliances", "marker": {"color": "#B6E880"}, "name": "Sub-Category=Appliances", "offsetgroup": "Sub-Category=Appliances", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Appliances"], "xaxis": "x", "y": [18138.005399999995], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Sub-Category=%{x}<br>Profit=%{y}", "legendgroup": "Sub-Category=Furnishings", "marker": {"color": "#FF97FF"}, "name": "Sub-Category=Furnishings", "offsetgroup": "Sub-Category=Furnishings", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Furnishings"], "xaxis": "x", "y": [13059.143599999983], "yaxis": "y"}, {"alignmentgroup": "True", "hoverlabel": {"namelength": 0}, "hovertemplate": "Sub-Category=%{x}<br>Profit=%{y}", "legendgroup": "Sub-Category=Envelopes", "marker": {"color": "#FECB52"}, "name": "Sub-Category=Envelopes", "offsetgroup": "Sub-Category=Envelopes", "orientation": "v", "show ...
#                         {"barmode": "relative", "legend": {"tracegroupgap": 0}, "template": {"d

# %%
px.pie(data_frame = prod_wise,
       names = "Sub-Category",
       hover_data=['Profit'],)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="b5000e5e-0ab7-44ce-b86e-29f0ad1cb8af" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b5000e5e-0ab7-44ce-b86e-29f0ad1cb8af")) {
#                     Plotly.newPlot(
#                         'b5000e5e-0ab7-44ce-b86e-29f0ad1cb8af',
#                         [{"customdata": [[55617.82490000001], [44515.7306], [41936.63569999993], [34053.56929999997], [30221.763299999995], [26590.166300000026], [21278.826399999998], [18138.005399999995], [13059.143599999983], [6964.176700000003], [6527.786999999998], [5546.253999999998], [3384.756899999999], [949.5182], [-1189.0994999999984], [-3472.5559999999978], [-17725.481100000008]], "domain": {"x": [0.0, 1.0], "y": [0.0, 1.0]}, "hoverlabel": {"namelength": 0}, "hovertemplate": "Profit=%{customdata[0]}<br>Sub-Category=%{label}", "labels": ["Copiers", "Phones", "Accessories", "Paper", "Binders", "Chairs", "Storage", "Appliances", "Furnishings", "Envelopes", "Art", "Labels", "Machines", "Fasteners", "Supplies", "Bookcases", "Tables"], "legendgroup": "", "name": "", "showlegend": true, "type": "pie"}],
#                         {"legend": {"tracegroupgap": 0}, "margin": {"t": 60}, "template": {"data": {"bar": [{"error_x": {"color": "#2a3f5f"}, "error_y": {"color": "#2a3f5f"}, "marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "bar"}], "barpolar": [{"marker": {"line": {"color": "#E5ECF6", "width": 0.5}}, "type": "barpolar"}], "carpet": [{"aaxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "baxis": {"endlinecolor": "#2a3f5f", "gridcolor": "white", "linecolor": "white", "minorgridcolor": "white", "startlinecolor": "#2a3f5f"}, "type": "carpet"}], "choropleth": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "choropleth"}], "contour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "contour"}], "contourcarpet": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "contourcarpet"}], "heatmap": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmap"}], "heatmapgl": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "heatmapgl"}], "histogram": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "histogram"}], "histogram2d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2d"}], "histogram2dcontour": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "colorscale": [[0.0, "#0d0887"], [0.1111111111111111, "#46039f"], [0.2222222222222222, "#7201a8"], [0.3333333333333333, "#9c179e"], [0.4444444444444444, "#bd3786"], [0.5555555555555556, "#d8576b"], [0.6666666666666666, "#ed7953"], [0.7777777777777778, "#fb9f3a"], [0.8888888888888888, "#fdca26"], [1.0, "#f0f921"]], "type": "histogram2dcontour"}], "mesh3d": [{"colorbar": {"outlinewidth": 0, "ticks": ""}, "type": "mesh3d"}], "parcoords": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "parcoords"}], "pie": [{"automargin": true, "type": "pie"}], "scatter": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter"}], "scatter3d": [{"line": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatter3d"}], "scattercarpet": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattercarpet"}], "scattergeo": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergeo"}], "scattergl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattergl"}], "scattermapbox": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scattermapbox"}], "scatterpolar": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpolar"}], "scatterpolargl": [{"marker": {"colorbar": {"outlinewidth": 0, "ticks": ""}}, "type": "scatterpola ...

# %%
prod_wise.reset_index().drop("index", axis = 1).style.bar()
# Out:
# <style  type="text/css" >
# #T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002row0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }#T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002row1_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 84.9%, transparent 84.9%);
#         }#T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002row2_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 81.3%, transparent 81.3%);
#         }#T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002row3_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 70.6%, transparent 70.6%);
#         }#T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002row4_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 65.4%, transparent 65.4%);
#         }#T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002row5_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 60.4%, transparent 60.4%);
#         }#T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002row6_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 53.2%, transparent 53.2%);
#         }#T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002row7_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 48.9%, transparent 48.9%);
#         }#T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002row8_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 42.0%, transparent 42.0%);
#         }#T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002row9_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 33.7%, transparent 33.7%);
#         }#T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002row10_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 33.1%, transparent 33.1%);
#         }#T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002row11_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 31.7%, transparent 31.7%);
#         }#T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002row12_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 28.8%, transparent 28.8%);
#         }#T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002row13_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 25.5%, transparent 25.5%);
#         }#T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002row14_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 22.5%, transparent 22.5%);
#         }#T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002row15_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 19.4%, transparent 19.4%);
#         }#T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002row16_col1{
#             width:  10em;
#              height:  80%;
#         }</style><table id="T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Sub-Category</th>        <th class="col_heading level0 col1" >Profit</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002row0_col0" class="data row0 col0" >Copiers</td>
#                         <td id="T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002row0_col1" class="data row0 col1" >55617.824900</td>
#             </tr>
#             <tr>
#                         <th id="T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002row1_col0" class="data row1 col0" >Phones</td>
#                         <td id="T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002row1_col1" class="data row1 col1" >44515.730600</td>
#             </tr>
#             <tr>
#                         <th id="T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002row2_col0" class="data row2 col0" >Accessories</td>
#                         <td id="T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002row2_col1" class="data row2 col1" >41936.635700</td>
#             </tr>
#             <tr>
#                         <th id="T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002row3_col0" class="data row3 col0" >Paper</td>
#                         <td id="T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002row3_col1" class="data row3 col1" >34053.569300</td>
#             </tr>
#             <tr>
#                         <th id="T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002row4_col0" class="data row4 col0" >Binders</td>
#                         <td id="T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002row4_col1" class="data row4 col1" >30221.763300</td>
#             </tr>
#             <tr>
#                         <th id="T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002row5_col0" class="data row5 col0" >Chairs</td>
#                         <td id="T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002row5_col1" class="data row5 col1" >26590.166300</td>
#             </tr>
#             <tr>
#                         <th id="T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002row6_col0" class="data row6 col0" >Storage</td>
#                         <td id="T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002row6_col1" class="data row6 col1" >21278.826400</td>
#             </tr>
#             <tr>
#                         <th id="T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002row7_col0" class="data row7 col0" >Appliances</td>
#                         <td id="T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002row7_col1" class="data row7 col1" >18138.005400</td>
#             </tr>
#             <tr>
#                         <th id="T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002row8_col0" class="data row8 col0" >Furnishings</td>
#                         <td id="T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002row8_col1" class="data row8 col1" >13059.143600</td>
#             </tr>
#             <tr>
#                         <th id="T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002row9_col0" class="data row9 col0" >Envelopes</td>
#                         <td id="T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002row9_col1" class="data row9 col1" >6964.176700</td>
#             </tr>
#             <tr>
#                         <th id="T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002row10_col0" class="data row10 col0" >Art</td>
#                         <td id="T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002row10_col1" class="data row10 col1" >6527.787000</td>
#             </tr>
#             <tr>
#                         <th id="T_9a9e6e7a_ff37_11eb_bfe4_0242ac1c0002le

# %% [markdown]
# ### **From above Graphs and dataframe, most profit is on `Copiers`**

# %% [markdown]
# ## **6.3- Analyzing top 20 cities where most products are sold**

# %%
city_wise = store_data[["City", "Sales", 'Profit']].groupby(['City'], as_index=False).sum().sort_values(by=['Sales', 'Profit'],
                                                                                        ascending=False)


px.bar(data_frame = city_wise.head(20), x = "City", y = "Sales",
       color="City",
       hover_data=['Sales', 'Profit'],
       title = "<b>Top 20 cities where most products are sold</b>")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d99fdaf0-b426-42b4-92e8-48f14c0bd917" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d99fdaf0-b426-42b4-92e8-48f14c0bd917")) {
#                     Plotly.newPlot(
#                         'd99fdaf0-b426-42b4-92e8-48f14c0bd917',
#                         [{"alignmentgroup": "True", "customdata": [[256368.161, 62036.98369999999]], "hoverlabel": {"namelength": 0}, "hovertemplate": "City=%{x}<br>Sales=%{customdata[0]}<br>Profit=%{customdata[1]}", "legendgroup": "City=New York City", "marker": {"color": "#636efa"}, "name": "City=New York City", "offsetgroup": "City=New York City", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["New York City"], "xaxis": "x", "y": [256368.161], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[175851.341, 30440.75789999997]], "hoverlabel": {"namelength": 0}, "hovertemplate": "City=%{x}<br>Sales=%{customdata[0]}<br>Profit=%{customdata[1]}", "legendgroup": "City=Los Angeles", "marker": {"color": "#EF553B"}, "name": "City=Los Angeles", "offsetgroup": "City=Los Angeles", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Los Angeles"], "xaxis": "x", "y": [175851.341], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[119540.742, 29156.0967]], "hoverlabel": {"namelength": 0}, "hovertemplate": "City=%{x}<br>Sales=%{customdata[0]}<br>Profit=%{customdata[1]}", "legendgroup": "City=Seattle", "marker": {"color": "#00cc96"}, "name": "City=Seattle", "offsetgroup": "City=Seattle", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Seattle"], "xaxis": "x", "y": [119540.742], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[112669.09199999993, 17507.385399999985]], "hoverlabel": {"namelength": 0}, "hovertemplate": "City=%{x}<br>Sales=%{customdata[0]}<br>Profit=%{customdata[1]}", "legendgroup": "City=San Francisco", "marker": {"color": "#ab63fa"}, "name": "City=San Francisco", "offsetgroup": "City=San Francisco", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["San Francisco"], "xaxis": "x", "y": [112669.09199999993], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[109077.01300000008, -13837.767400000012]], "hoverlabel": {"namelength": 0}, "hovertemplate": "City=%{x}<br>Sales=%{customdata[0]}<br>Profit=%{customdata[1]}", "legendgroup": "City=Philadelphia", "marker": {"color": "#FFA15A"}, "name": "City=Philadelphia", "offsetgroup": "City=Philadelphia", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Philadelphia"], "xaxis": "x", "y": [109077.01300000008], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[64504.76039999994, -10153.548499999997]], "hoverlabel": {"namelength": 0}, "hovertemplate": "City=%{x}<br>Sales=%{customdata[0]}<br>Profit=%{customdata[1]}", "legendgroup": "City=Houston", "marker": {"color": "#19d3f3"}, "name": "City=Houston", "offsetgroup": "City=Houston", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Houston"], "xaxis": "x", "y": [64504.76039999994], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[48539.54100000004, -6654.568799999997]], "hoverlabel": {"namelength": 0}, "hovertemplate": "City=%{x}<br>Sales=%{customdata[0]}<br>Profit=%{customdata[1]}", "legendgroup": "City=Chicago", "marker": {"color": "#FF6692"}, "name": "City=Chicago", "offsetgroup": "City=Chicago", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Chicago"], "xaxis": "x", "y": [48539.54100000004], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[47521.028999999995, 6377.196000000003]], "hoverlabel": {"namelength": 0}, "hovertemplate": "City=%{x}<br>Sales=%{customdata[0]}<br>Profit=%{customdata[1]}", "legendgroup": "City=San Diego", "marker": {"color": "#B6E880"}, "name": "City=San Diego", "offsetgroup": "City=San Diego", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["San Diego"], "xaxis": "x", "y": [47521.028999999995], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[44713.183, -2323.8349999999996]], "hoverlabel": {"namelength": 0}, "hovertemplate": "City=%{x}<br>Sales=%{customdata[0]}<br>P ...

# %% [markdown]
# ### **New York is a city where most products are sold**

# %%
city_wise.reset_index().drop('index', axis = 1).head(20).style.bar()
# Out:
# <style  type="text/css" >
# #T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row0_col1,#T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row0_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }#T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row1_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 65.9%, transparent 65.9%);
#         }#T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row1_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 58.4%, transparent 58.4%);
#         }#T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row2_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 42.1%, transparent 42.1%);
#         }#T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row2_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 56.7%, transparent 56.7%);
#         }#T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row3_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 39.2%, transparent 39.2%);
#         }#T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row3_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 41.3%, transparent 41.3%);
#         }#T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row4_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 37.7%, transparent 37.7%);
#         }#T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row4_col2,#T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row19_col1{
#             width:  10em;
#              height:  80%;
#         }#T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row5_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 18.8%, transparent 18.8%);
#         }#T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row5_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 4.9%, transparent 4.9%);
#         }#T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row6_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 12.0%, transparent 12.0%);
#         }#T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row6_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.5%, transparent 9.5%);
#         }#T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row7_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 11.6%, transparent 11.6%);
#         }#T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row7_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 26.6%, transparent 26.6%);
#         }#T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row8_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.4%, transparent 10.4%);
#         }#T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row8_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 15.2%, transparent 15.2%);
#         }#T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row9_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.7%, transparent 9.7%);
#         }#T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row9_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 26.4%, transparent 26.4%);
#         }#T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row10_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.4%, transparent 9.4%);
#         }#T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row10_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 35.6%, transparent 35.6%);
#         }#T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row11_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 7.9%, transparent 7.9%);
#         }#T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row11_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 26.0%, transparent 26.0%);
#         }#T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row12_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.6%, transparent 3.6%);
#         }#T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row12_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 25.9%, transparent 25.9%);
#         }#T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row13_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.2%, transparent 2.2%);
#         }#T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row13_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 25.6%, transparent 25.6%);
#         }#T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row14_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.1%, transparent 2.1%);
#         }#T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row14_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 31.4%, transparent 31.4%);
#         }#T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row15_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.0%, transparent 2.0%);
#         }#T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row15_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 28.2%, transparent 28.2%);
#         }#T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row16_col1,#T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row17_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.7%, transparent 0.7%);
#         }#T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row16_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.6%, transparent 8.6%);
#         }#T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row17_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 13.5%, transparent 13.5%);
#         }#T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row18_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0.0%);
#         }#T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row18_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 23.7%, transparent 23.7%);
#         }#T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row19_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 14.5%, transparent 14.5%);
#         }</style><table id="T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >City</th>        <th class="col_heading level0 col1" >Sales</th>        <th class="col_heading level0 col2" >Profit</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row0_col0" class="data row0 col0" >New York City</td>
#                         <td id="T_9b0be89c_ff37_11eb_bfe4_0242ac1c0002row0_col1" class="data row0 col1" >256368.161000</td>
#                         <td id="T_9b0

# %% [markdown]
# ## **6.4- Analyzing buttom 20 cities where products are sold**

# %%
city_wise = store_data[["City", "Sales", 'Profit']].groupby(['City'], as_index=False).sum().sort_values(by=['Sales', 'Profit'],
                                                                                        ascending=False)


px.bar(data_frame = city_wise.tail(20), x = "City", y = "Sales",
       color="City",
       hover_data=['Sales', 'Profit'],
       title = "<b>Buttom 20 cities where most products are sold</b>")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="0ee9790e-dcc2-4816-afec-bc5f7504032f" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("0ee9790e-dcc2-4816-afec-bc5f7504032f")) {
#                     Plotly.newPlot(
#                         '0ee9790e-dcc2-4816-afec-bc5f7504032f',
#                         [{"alignmentgroup": "True", "customdata": [[14.77, 7.156700000000001]], "hoverlabel": {"namelength": 0}, "hovertemplate": "City=%{x}<br>Sales=%{customdata[0]}<br>Profit=%{customdata[1]}", "legendgroup": "City=New Brunswick", "marker": {"color": "#636efa"}, "name": "City=New Brunswick", "offsetgroup": "City=New Brunswick", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["New Brunswick"], "xaxis": "x", "y": [14.77], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[14.112, 1.2348]], "hoverlabel": {"namelength": 0}, "hovertemplate": "City=%{x}<br>Sales=%{customdata[0]}<br>Profit=%{customdata[1]}", "legendgroup": "City=Arlington Heights", "marker": {"color": "#EF553B"}, "name": "City=Arlington Heights", "offsetgroup": "City=Arlington Heights", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Arlington Heights"], "xaxis": "x", "y": [14.112], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[14.015999999999998, 4.7304]], "hoverlabel": {"namelength": 0}, "hovertemplate": "City=%{x}<br>Sales=%{customdata[0]}<br>Profit=%{customdata[1]}", "legendgroup": "City=Chapel Hill", "marker": {"color": "#00cc96"}, "name": "City=Chapel Hill", "offsetgroup": "City=Chapel Hill", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Chapel Hill"], "xaxis": "x", "y": [14.015999999999998], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[11.85, 3.792]], "hoverlabel": {"namelength": 0}, "hovertemplate": "City=%{x}<br>Sales=%{customdata[0]}<br>Profit=%{customdata[1]}", "legendgroup": "City=Rock Hill", "marker": {"color": "#ab63fa"}, "name": "City=Rock Hill", "offsetgroup": "City=Rock Hill", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Rock Hill"], "xaxis": "x", "y": [11.85], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[10.368, 3.6288]], "hoverlabel": {"namelength": 0}, "hovertemplate": "City=%{x}<br>Sales=%{customdata[0]}<br>Profit=%{customdata[1]}", "legendgroup": "City=Baytown", "marker": {"color": "#FFA15A"}, "name": "City=Baytown", "offsetgroup": "City=Baytown", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Baytown"], "xaxis": "x", "y": [10.368], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[9.99, 4.4955]], "hoverlabel": {"namelength": 0}, "hovertemplate": "City=%{x}<br>Sales=%{customdata[0]}<br>Profit=%{customdata[1]}", "legendgroup": "City=Iowa City", "marker": {"color": "#19d3f3"}, "name": "City=Iowa City", "offsetgroup": "City=Iowa City", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Iowa City"], "xaxis": "x", "y": [9.99], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[8.952, -14.7708]], "hoverlabel": {"namelength": 0}, "hovertemplate": "City=%{x}<br>Sales=%{customdata[0]}<br>Profit=%{customdata[1]}", "legendgroup": "City=Romeoville", "marker": {"color": "#FF6692"}, "name": "City=Romeoville", "offsetgroup": "City=Romeoville", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Romeoville"], "xaxis": "x", "y": [8.952], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[8.288, 2.6936]], "hoverlabel": {"namelength": 0}, "hovertemplate": "City=%{x}<br>Sales=%{customdata[0]}<br>Profit=%{customdata[1]}", "legendgroup": "City=Billings", "marker": {"color": "#B6E880"}, "name": "City=Billings", "offsetgroup": "City=Billings", "orientation": "v", "showlegend": true, "textposition": "auto", "type": "bar", "x": ["Billings"], "xaxis": "x", "y": [8.288], "yaxis": "y"}, {"alignmentgroup": "True", "customdata": [[7.824, 2.9339999999999997]], "hoverlabel": {"namelength": 0}, "hovertemplate": "City=%{x}<br>Sales=%{customdata[0]}<br>Profit=%{customdata[1]}", "legendgroup": "City=Port Orange", "marker": {"color": "#FF97FF"}, "name": "City=Port Orange", "offsetgroup": "City=Port Orange", "orientation": "v", "showlegend": ...

# %% [markdown]
# ### **Abilene is a city where less products are sold**

# %%
city_wise.reset_index().drop('index', axis = 1).tail(20).style.bar()
# Out:
# <style  type="text/css" >
# #T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002row0_col1,#T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002row0_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }#T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002row1_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 95.1%, transparent 95.1%);
#         }#T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002row1_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 73.0%, transparent 73.0%);
#         }#T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002row2_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 94.4%, transparent 94.4%);
#         }#T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002row2_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 88.9%, transparent 88.9%);
#         }#T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002row3_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 78.2%, transparent 78.2%);
#         }#T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002row3_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 84.7%, transparent 84.7%);
#         }#T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002row4_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 67.1%, transparent 67.1%);
#         }#T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002row4_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 83.9%, transparent 83.9%);
#         }#T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002row5_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 64.3%, transparent 64.3%);
#         }#T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002row5_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 87.9%, transparent 87.9%);
#         }#T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002row6_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 56.5%, transparent 56.5%);
#         }#T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002row6_col2,#T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002row19_col1{
#             width:  10em;
#              height:  80%;
#         }#T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002row7_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 51.5%, transparent 51.5%);
#         }#T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002row7_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 79.6%, transparent 79.6%);
#         }#T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002row8_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 48.1%, transparent 48.1%);
#         }#T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002row8_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 80.7%, transparent 80.7%);
#         }#T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002row9_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 41.4%, transparent 41.4%);
#         }#T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002row9_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.0%, transparent 20.0%);
#         }#T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002row10_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 37.2%, transparent 37.2%);
#         }#T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002row10_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 23.8%, transparent 23.8%);
#         }#T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002row11_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 34.4%, transparent 34.4%);
#         }#T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002row11_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 76.9%, transparent 76.9%);
#         }#T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002row12_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 26.7%, transparent 26.7%);
#         }#T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002row12_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 78.0%, transparent 78.0%);
#         }#T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002row13_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 21.7%, transparent 21.7%);
#         }#T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002row13_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 73.8%, transparent 73.8%);
#         }#T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002row14_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 16.7%, transparent 16.7%);
#         }#T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002row14_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 72.8%, transparent 72.8%);
#         }#T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002row15_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.6%, transparent 10.6%);
#         }#T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002row15_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 58.4%, transparent 58.4%);
#         }#T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002row16_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 6.1%, transparent 6.1%);
#         }#T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002row16_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 60.6%, transparent 60.6%);
#         }#T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002row17_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.0%, transparent 5.0%);
#         }#T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002row17_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 68.1%, transparent 68.1%);
#         }#T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002row18_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.2%, transparent 3.2%);
#         }#T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002row18_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 61.0%, transparent 61.0%);
#         }#T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002row19_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 50.2%, transparent 50.2%);
#         }</style><table id="T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >City</th>        <th class="col_heading level0 col1" >Sales</th>        <th class="col_heading level0 col2" >Profit</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002level0_row0" class="row_heading level0 row0" >511</th>
#                         <td id="T_9b5bc13c_ff37_11eb_bfe4_0242ac1c0002row0_col0" class="data row0 col0" >New Brunswick</

# %% [markdown]
# ## **6.5- Top words in City feature**

# %%
text = ' '.join(store_data['City'].str.lower())

wordcloud = WordCloud(width = 2000, height = 900, 
                      background_color ='black',
                      collocations=False,
                      max_words=5000,
                      min_font_size = 15).generate(text)
    
plt.figure(figsize=(12, 8), facecolor = 'k', edgecolor = 'k' )
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0) 
plt.show()

# %% [markdown]
# ## **6.6- Top words in Sub-Category**

# %%
text = ' '.join(store_data['Sub-Category'].str.lower())

wordcloud = WordCloud(width = 2000, height = 900, 
                      background_color ='black',
                      collocations=False,
                      max_words=5000,
                      min_font_size = 15).generate(text)
    
plt.figure(figsize=(12, 8), facecolor = 'k', edgecolor = 'k' )
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0) 
plt.show()
