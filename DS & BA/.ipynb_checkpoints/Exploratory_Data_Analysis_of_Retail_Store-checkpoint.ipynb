# %% [markdown]
# # **1- Importing required libraries**

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import missingno as msno
from wordcloud import WordCloud

sns.set(style="darkgrid")

# %% [markdown]
# # **2- Reading data**

# %%
store_data = pd.read_csv("../SuperstoreData.csv")

# %%
store_data.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# 3      0.45 -383.0310
# 4      0.20    2.5164

# %% [markdown]
# # **3- Checking meta information of dataframe**

# %%
store_data.shape
# Out:
# (9994, 13)

# %%
store_data.dtypes
# Out:
# Ship Mode        object
# Segment          object
# Country          object
# City             object
# State            object
# Postal Code       int64
# Region           object
# Category         object
# Sub-Category     object
# Sales           float64
# Quantity          int64
# Discount        float64
# Profit          float64
# dtype: object

# %% [markdown]
# ## **4- Checking statistical information of dataframe**

# %%
store_data.describe()[["Sales","Quantity", 'Discount', 'Profit']].T.style.bar(subset=['mean'], color='#205ff2')\
                                                .background_gradient(subset=['std'], cmap='Reds')\
                                                .background_gradient(subset=['50%'], cmap='coolwarm')
# Out:
# <style  type="text/css" >
# #T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 100.0%, transparent 100.0%);
#         }#T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row0_col2{
#             background-color:  #67000d;
#             color:  #f1f1f1;
#         }#T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row0_col5{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }#T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row1_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 1.6%, transparent 1.6%);
#         }#T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row1_col2,#T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row2_col2{
#             background-color:  #fff5f0;
#             color:  #000000;
#         }#T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row1_col5{
#             background-color:  #4a63d3;
#             color:  #f1f1f1;
#         }#T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row2_col1{
#             width:  10em;
#              height:  80%;
#         }#T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row2_col5{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row3_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#205ff2 12.4%, transparent 12.4%);
#         }#T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row3_col2{
#             background-color:  #fc9272;
#             color:  #000000;
#         }#T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row3_col5{
#             background-color:  #6b8df0;
#             color:  #000000;
#         }</style><table id="T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >count</th>        <th class="col_heading level0 col1" >mean</th>        <th class="col_heading level0 col2" >std</th>        <th class="col_heading level0 col3" >min</th>        <th class="col_heading level0 col4" >25%</th>        <th class="col_heading level0 col5" >50%</th>        <th class="col_heading level0 col6" >75%</th>        <th class="col_heading level0 col7" >max</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1level0_row0" class="row_heading level0 row0" >Sales</th>
#                         <td id="T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row0_col0" class="data row0 col0" >9994.000000</td>
#                         <td id="T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row0_col1" class="data row0 col1" >229.858001</td>
#                         <td id="T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row0_col2" class="data row0 col2" >623.245101</td>
#                         <td id="T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row0_col3" class="data row0 col3" >0.444000</td>
#                         <td id="T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row0_col4" class="data row0 col4" >17.280000</td>
#                         <td id="T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row0_col5" class="data row0 col5" >54.490000</td>
#                         <td id="T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row0_col6" class="data row0 col6" >209.940000</td>
#                         <td id="T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row0_col7" class="data row0 col7" >22638.480000</td>
#             </tr>
#             <tr>
#                         <th id="T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1level0_row1" class="row_heading level0 row1" >Quantity</th>
#                         <td id="T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row1_col0" class="data row1 col0" >9994.000000</td>
#                         <td id="T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row1_col1" class="data row1 col1" >3.789574</td>
#                         <td id="T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row1_col2" class="data row1 col2" >2.225110</td>
#                         <td id="T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row1_col3" class="data row1 col3" >1.000000</td>
#                         <td id="T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row1_col4" class="data row1 col4" >2.000000</td>
#                         <td id="T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row1_col5" class="data row1 col5" >3.000000</td>
#                         <td id="T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row1_col6" class="data row1 col6" >5.000000</td>
#                         <td id="T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row1_col7" class="data row1 col7" >14.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1level0_row2" class="row_heading level0 row2" >Discount</th>
#                         <td id="T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row2_col0" class="data row2 col0" >9994.000000</td>
#                         <td id="T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row2_col1" class="data row2 col1" >0.156203</td>
#                         <td id="T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row2_col2" class="data row2 col2" >0.206452</td>
#                         <td id="T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row2_col3" class="data row2 col3" >0.000000</td>
#                         <td id="T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row2_col4" class="data row2 col4" >0.000000</td>
#                         <td id="T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row2_col5" class="data row2 col5" >0.200000</td>
#                         <td id="T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row2_col6" class="data row2 col6" >0.200000</td>
#                         <td id="T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row2_col7" class="data row2 col7" >0.800000</td>
#             </tr>
#             <tr>
#                         <th id="T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1level0_row3" class="row_heading level0 row3" >Profit</th>
#                         <td id="T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row3_col0" class="data row3 col0" >9994.000000</td>
#                         <td id="T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row3_col1" class="data row3 col1" >28.656896</td>
#                         <td id="T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row3_col2" class="data row3 col2" >234.260108</td>
#                         <td id="T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row3_col3" class="data row3 col3" >-6599.978000</td>
#                         <td id="T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row3_col4" class="data row3 col4" >1.728750</td>
#                         <td id="T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row3_col5" class="data row3 col5" >8.666500</td>
#                         <td id="T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row3_col6" class="data row3 col6" >29.364000</td>
#                         <td id="T_89e7ee6a_00e7_11ec_9aaa_b352c449eab1row3_col7" class="data row3 col7" >8399.976000</td>
#             </tr>
#     </tbody></table>

# %% [markdown]
# ## **5- Checking for NaN values**

# %%
msno.bar(store_data, color='b', figsize = (12,6));

# %% [markdown]
# **So none of the column contains NaN value**

# %% [markdown]
# ---
# ## Note: As Interactive charts are not displayed in github, So I save charts in `svg` form in plotly
# ---

# %% [markdown]
# # **6- Visualization**

# %%
store_data['Ship Mode'].value_counts()
# Out:
# Standard Class    5968
# Second Class      1945
# First Class       1538
# Same Day           543
# Name: Ship Mode, dtype: int64

# %%
fig = px.histogram(store_data,
             x = "Ship Mode",
             color='Segment',
             title = "<b>Counts in Ship Mode</b>",)

fig.show('svg')

# %% [markdown]
# **Above histogram shows that Ship Mode has 4 categories and Standard Class has more counts then others. Also In Standard Class more Segmants belongs to Consumer class then Corporate and then Home Office**

# %% [markdown]
# ## **6.1- Analyze Segment**

# %%
store_data['Segment'].value_counts()
# Out:
# Consumer       5191
# Corporate      3020
# Home Office    1783
# Name: Segment, dtype: int64

# %%
fig = px.pie(store_data, names = "Segment",
             title = "<b>Counts in Segment</b>",
             hole = 0.5)

fig.show('svg')

# %% [markdown]
# ## **6.2- Analyzing which product Sub-category has more profit**

# %%
prod_wise = store_data[["Sub-Category", "Profit"]].groupby(['Sub-Category'],
                                                      as_index=False).sum().sort_values(by='Profit',
                                                                                        ascending=False)


fig = px.bar(data_frame = prod_wise, x = "Sub-Category", y = "Profit",
       color="Sub-Category",
       title = "<b>Product Category Vs Profit</b>")

fig.show('svg')

# %%
fig = px.pie(data_frame = prod_wise,
       names = "Sub-Category",
       hover_data=['Profit'],)


fig.show('svg')

# %%
prod_wise.reset_index().drop("index", axis = 1).style.bar()
# Out:
# <style  type="text/css" >
# #T_8b8789d8_00e7_11ec_9aaa_b352c449eab1row0_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }#T_8b8789d8_00e7_11ec_9aaa_b352c449eab1row1_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 84.9%, transparent 84.9%);
#         }#T_8b8789d8_00e7_11ec_9aaa_b352c449eab1row2_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 81.3%, transparent 81.3%);
#         }#T_8b8789d8_00e7_11ec_9aaa_b352c449eab1row3_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 70.6%, transparent 70.6%);
#         }#T_8b8789d8_00e7_11ec_9aaa_b352c449eab1row4_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 65.4%, transparent 65.4%);
#         }#T_8b8789d8_00e7_11ec_9aaa_b352c449eab1row5_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 60.4%, transparent 60.4%);
#         }#T_8b8789d8_00e7_11ec_9aaa_b352c449eab1row6_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 53.2%, transparent 53.2%);
#         }#T_8b8789d8_00e7_11ec_9aaa_b352c449eab1row7_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 48.9%, transparent 48.9%);
#         }#T_8b8789d8_00e7_11ec_9aaa_b352c449eab1row8_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 42.0%, transparent 42.0%);
#         }#T_8b8789d8_00e7_11ec_9aaa_b352c449eab1row9_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 33.7%, transparent 33.7%);
#         }#T_8b8789d8_00e7_11ec_9aaa_b352c449eab1row10_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 33.1%, transparent 33.1%);
#         }#T_8b8789d8_00e7_11ec_9aaa_b352c449eab1row11_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 31.7%, transparent 31.7%);
#         }#T_8b8789d8_00e7_11ec_9aaa_b352c449eab1row12_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 28.8%, transparent 28.8%);
#         }#T_8b8789d8_00e7_11ec_9aaa_b352c449eab1row13_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 25.5%, transparent 25.5%);
#         }#T_8b8789d8_00e7_11ec_9aaa_b352c449eab1row14_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 22.5%, transparent 22.5%);
#         }#T_8b8789d8_00e7_11ec_9aaa_b352c449eab1row15_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 19.4%, transparent 19.4%);
#         }#T_8b8789d8_00e7_11ec_9aaa_b352c449eab1row16_col1{
#             width:  10em;
#              height:  80%;
#         }</style><table id="T_8b8789d8_00e7_11ec_9aaa_b352c449eab1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >Sub-Category</th>        <th class="col_heading level0 col1" >Profit</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8b8789d8_00e7_11ec_9aaa_b352c449eab1level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_8b8789d8_00e7_11ec_9aaa_b352c449eab1row0_col0" class="data row0 col0" >Copiers</td>
#                         <td id="T_8b8789d8_00e7_11ec_9aaa_b352c449eab1row0_col1" class="data row0 col1" >55617.824900</td>
#             </tr>
#             <tr>
#                         <th id="T_8b8789d8_00e7_11ec_9aaa_b352c449eab1level0_row1" class="row_heading level0 row1" >1</th>
#                         <td id="T_8b8789d8_00e7_11ec_9aaa_b352c449eab1row1_col0" class="data row1 col0" >Phones</td>
#                         <td id="T_8b8789d8_00e7_11ec_9aaa_b352c449eab1row1_col1" class="data row1 col1" >44515.730600</td>
#             </tr>
#             <tr>
#                         <th id="T_8b8789d8_00e7_11ec_9aaa_b352c449eab1level0_row2" class="row_heading level0 row2" >2</th>
#                         <td id="T_8b8789d8_00e7_11ec_9aaa_b352c449eab1row2_col0" class="data row2 col0" >Accessories</td>
#                         <td id="T_8b8789d8_00e7_11ec_9aaa_b352c449eab1row2_col1" class="data row2 col1" >41936.635700</td>
#             </tr>
#             <tr>
#                         <th id="T_8b8789d8_00e7_11ec_9aaa_b352c449eab1level0_row3" class="row_heading level0 row3" >3</th>
#                         <td id="T_8b8789d8_00e7_11ec_9aaa_b352c449eab1row3_col0" class="data row3 col0" >Paper</td>
#                         <td id="T_8b8789d8_00e7_11ec_9aaa_b352c449eab1row3_col1" class="data row3 col1" >34053.569300</td>
#             </tr>
#             <tr>
#                         <th id="T_8b8789d8_00e7_11ec_9aaa_b352c449eab1level0_row4" class="row_heading level0 row4" >4</th>
#                         <td id="T_8b8789d8_00e7_11ec_9aaa_b352c449eab1row4_col0" class="data row4 col0" >Binders</td>
#                         <td id="T_8b8789d8_00e7_11ec_9aaa_b352c449eab1row4_col1" class="data row4 col1" >30221.763300</td>
#             </tr>
#             <tr>
#                         <th id="T_8b8789d8_00e7_11ec_9aaa_b352c449eab1level0_row5" class="row_heading level0 row5" >5</th>
#                         <td id="T_8b8789d8_00e7_11ec_9aaa_b352c449eab1row5_col0" class="data row5 col0" >Chairs</td>
#                         <td id="T_8b8789d8_00e7_11ec_9aaa_b352c449eab1row5_col1" class="data row5 col1" >26590.166300</td>
#             </tr>
#             <tr>
#                         <th id="T_8b8789d8_00e7_11ec_9aaa_b352c449eab1level0_row6" class="row_heading level0 row6" >6</th>
#                         <td id="T_8b8789d8_00e7_11ec_9aaa_b352c449eab1row6_col0" class="data row6 col0" >Storage</td>
#                         <td id="T_8b8789d8_00e7_11ec_9aaa_b352c449eab1row6_col1" class="data row6 col1" >21278.826400</td>
#             </tr>
#             <tr>
#                         <th id="T_8b8789d8_00e7_11ec_9aaa_b352c449eab1level0_row7" class="row_heading level0 row7" >7</th>
#                         <td id="T_8b8789d8_00e7_11ec_9aaa_b352c449eab1row7_col0" class="data row7 col0" >Appliances</td>
#                         <td id="T_8b8789d8_00e7_11ec_9aaa_b352c449eab1row7_col1" class="data row7 col1" >18138.005400</td>
#             </tr>
#             <tr>
#                         <th id="T_8b8789d8_00e7_11ec_9aaa_b352c449eab1level0_row8" class="row_heading level0 row8" >8</th>
#                         <td id="T_8b8789d8_00e7_11ec_9aaa_b352c449eab1row8_col0" class="data row8 col0" >Furnishings</td>
#                         <td id="T_8b8789d8_00e7_11ec_9aaa_b352c449eab1row8_col1" class="data row8 col1" >13059.143600</td>
#             </tr>
#             <tr>
#                         <th id="T_8b8789d8_00e7_11ec_9aaa_b352c449eab1level0_row9" class="row_heading level0 row9" >9</th>
#                         <td id="T_8b8789d8_00e7_11ec_9aaa_b352c449eab1row9_col0" class="data row9 col0" >Envelopes</td>
#                         <td id="T_8b8789d8_00e7_11ec_9aaa_b352c449eab1row9_col1" class="data row9 col1" >6964.176700</td>
#             </tr>
#             <tr>
#                         <th id="T_8b8789d8_00e7_11ec_9aaa_b352c449eab1level0_row10" class="row_heading level0 row10" >10</th>
#                         <td id="T_8b8789d8_00e7_11ec_9aaa_b352c449eab1row10_col0" class="data row10 col0" >Art</td>
#                         <td id="T_8b8789d8_00e7_11ec_9aaa_b352c449eab1row10_col1" class="data row10 col1" >6527.787000</td>
#             </tr>
#             <tr>
#                         <th id="T_8b8789d8_00e7_11ec_9aaa_b352c449eab1le

# %% [markdown]
# ### **From above Graphs and dataframe, most profit is on `Copiers`**

# %% [markdown]
# ## **6.3- Analyzing top 20 cities where most products are sold**

# %%
city_wise = store_data[["City", "Sales", 'Profit']].groupby(['City'], as_index=False).sum().sort_values(by=['Sales', 'Profit'],
                                                                                        ascending=False)


fig = px.bar(data_frame = city_wise.head(20), x = "City", y = "Sales",
       color="City",
       hover_data=['Sales', 'Profit'],
       title = "<b>Top 20 cities where most products are sold</b>")

fig.show('svg')

# %% [markdown]
# ### **New York is a city where most products are sold**

# %%
city_wise.reset_index().drop('index', axis = 1).head(20).style.bar()
# Out:
# <style  type="text/css" >
# #T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row0_col1,#T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row0_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }#T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row1_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 65.9%, transparent 65.9%);
#         }#T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row1_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 58.4%, transparent 58.4%);
#         }#T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row2_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 42.1%, transparent 42.1%);
#         }#T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row2_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 56.7%, transparent 56.7%);
#         }#T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row3_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 39.2%, transparent 39.2%);
#         }#T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row3_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 41.3%, transparent 41.3%);
#         }#T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row4_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 37.7%, transparent 37.7%);
#         }#T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row4_col2,#T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row19_col1{
#             width:  10em;
#              height:  80%;
#         }#T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row5_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 18.8%, transparent 18.8%);
#         }#T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row5_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 4.9%, transparent 4.9%);
#         }#T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row6_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 12.0%, transparent 12.0%);
#         }#T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row6_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.5%, transparent 9.5%);
#         }#T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row7_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 11.6%, transparent 11.6%);
#         }#T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row7_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 26.6%, transparent 26.6%);
#         }#T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row8_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.4%, transparent 10.4%);
#         }#T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row8_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 15.2%, transparent 15.2%);
#         }#T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row9_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.7%, transparent 9.7%);
#         }#T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row9_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 26.4%, transparent 26.4%);
#         }#T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row10_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 9.4%, transparent 9.4%);
#         }#T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row10_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 35.6%, transparent 35.6%);
#         }#T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row11_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 7.9%, transparent 7.9%);
#         }#T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row11_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 26.0%, transparent 26.0%);
#         }#T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row12_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.6%, transparent 3.6%);
#         }#T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row12_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 25.9%, transparent 25.9%);
#         }#T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row13_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.2%, transparent 2.2%);
#         }#T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row13_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 25.6%, transparent 25.6%);
#         }#T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row14_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.1%, transparent 2.1%);
#         }#T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row14_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 31.4%, transparent 31.4%);
#         }#T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row15_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 2.0%, transparent 2.0%);
#         }#T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row15_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 28.2%, transparent 28.2%);
#         }#T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row16_col1,#T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row17_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.7%, transparent 0.7%);
#         }#T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row16_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 8.6%, transparent 8.6%);
#         }#T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row17_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 13.5%, transparent 13.5%);
#         }#T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row18_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 0.0%, transparent 0.0%);
#         }#T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row18_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 23.7%, transparent 23.7%);
#         }#T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row19_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 14.5%, transparent 14.5%);
#         }</style><table id="T_8bc884a6_00e7_11ec_9aaa_b352c449eab1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >City</th>        <th class="col_heading level0 col1" >Sales</th>        <th class="col_heading level0 col2" >Profit</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8bc884a6_00e7_11ec_9aaa_b352c449eab1level0_row0" class="row_heading level0 row0" >0</th>
#                         <td id="T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row0_col0" class="data row0 col0" >New York City</td>
#                         <td id="T_8bc884a6_00e7_11ec_9aaa_b352c449eab1row0_col1" class="data row0 col1" >256368.161000</td>
#                         <td id="T_8bc

# %% [markdown]
# ## **6.4- Analyzing buttom 20 cities where products are sold**

# %%
city_wise = store_data[["City", "Sales", 'Profit']].groupby(['City'], as_index=False).sum().sort_values(by=['Sales', 'Profit'],
                                                                                        ascending=False)


fig = px.bar(data_frame = city_wise.tail(20), x = "City", y = "Sales",
       color="City",
       hover_data=['Sales', 'Profit'],
       title = "<b>Buttom 20 cities where most products are sold</b>")

fig.show('svg')

# %% [markdown]
# ### **Abilene is a city where less products are sold**

# %%
city_wise.reset_index().drop('index', axis = 1).tail(20).style.bar()
# Out:
# <style  type="text/css" >
# #T_8c0a3392_00e7_11ec_9aaa_b352c449eab1row0_col1,#T_8c0a3392_00e7_11ec_9aaa_b352c449eab1row0_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 100.0%, transparent 100.0%);
#         }#T_8c0a3392_00e7_11ec_9aaa_b352c449eab1row1_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 95.1%, transparent 95.1%);
#         }#T_8c0a3392_00e7_11ec_9aaa_b352c449eab1row1_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 73.0%, transparent 73.0%);
#         }#T_8c0a3392_00e7_11ec_9aaa_b352c449eab1row2_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 94.4%, transparent 94.4%);
#         }#T_8c0a3392_00e7_11ec_9aaa_b352c449eab1row2_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 88.9%, transparent 88.9%);
#         }#T_8c0a3392_00e7_11ec_9aaa_b352c449eab1row3_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 78.2%, transparent 78.2%);
#         }#T_8c0a3392_00e7_11ec_9aaa_b352c449eab1row3_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 84.7%, transparent 84.7%);
#         }#T_8c0a3392_00e7_11ec_9aaa_b352c449eab1row4_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 67.1%, transparent 67.1%);
#         }#T_8c0a3392_00e7_11ec_9aaa_b352c449eab1row4_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 83.9%, transparent 83.9%);
#         }#T_8c0a3392_00e7_11ec_9aaa_b352c449eab1row5_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 64.3%, transparent 64.3%);
#         }#T_8c0a3392_00e7_11ec_9aaa_b352c449eab1row5_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 87.9%, transparent 87.9%);
#         }#T_8c0a3392_00e7_11ec_9aaa_b352c449eab1row6_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 56.5%, transparent 56.5%);
#         }#T_8c0a3392_00e7_11ec_9aaa_b352c449eab1row6_col2,#T_8c0a3392_00e7_11ec_9aaa_b352c449eab1row19_col1{
#             width:  10em;
#              height:  80%;
#         }#T_8c0a3392_00e7_11ec_9aaa_b352c449eab1row7_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 51.5%, transparent 51.5%);
#         }#T_8c0a3392_00e7_11ec_9aaa_b352c449eab1row7_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 79.6%, transparent 79.6%);
#         }#T_8c0a3392_00e7_11ec_9aaa_b352c449eab1row8_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 48.1%, transparent 48.1%);
#         }#T_8c0a3392_00e7_11ec_9aaa_b352c449eab1row8_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 80.7%, transparent 80.7%);
#         }#T_8c0a3392_00e7_11ec_9aaa_b352c449eab1row9_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 41.4%, transparent 41.4%);
#         }#T_8c0a3392_00e7_11ec_9aaa_b352c449eab1row9_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 20.0%, transparent 20.0%);
#         }#T_8c0a3392_00e7_11ec_9aaa_b352c449eab1row10_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 37.2%, transparent 37.2%);
#         }#T_8c0a3392_00e7_11ec_9aaa_b352c449eab1row10_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 23.8%, transparent 23.8%);
#         }#T_8c0a3392_00e7_11ec_9aaa_b352c449eab1row11_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 34.4%, transparent 34.4%);
#         }#T_8c0a3392_00e7_11ec_9aaa_b352c449eab1row11_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 76.9%, transparent 76.9%);
#         }#T_8c0a3392_00e7_11ec_9aaa_b352c449eab1row12_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 26.7%, transparent 26.7%);
#         }#T_8c0a3392_00e7_11ec_9aaa_b352c449eab1row12_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 78.0%, transparent 78.0%);
#         }#T_8c0a3392_00e7_11ec_9aaa_b352c449eab1row13_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 21.7%, transparent 21.7%);
#         }#T_8c0a3392_00e7_11ec_9aaa_b352c449eab1row13_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 73.8%, transparent 73.8%);
#         }#T_8c0a3392_00e7_11ec_9aaa_b352c449eab1row14_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 16.7%, transparent 16.7%);
#         }#T_8c0a3392_00e7_11ec_9aaa_b352c449eab1row14_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 72.8%, transparent 72.8%);
#         }#T_8c0a3392_00e7_11ec_9aaa_b352c449eab1row15_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 10.6%, transparent 10.6%);
#         }#T_8c0a3392_00e7_11ec_9aaa_b352c449eab1row15_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 58.4%, transparent 58.4%);
#         }#T_8c0a3392_00e7_11ec_9aaa_b352c449eab1row16_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 6.1%, transparent 6.1%);
#         }#T_8c0a3392_00e7_11ec_9aaa_b352c449eab1row16_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 60.6%, transparent 60.6%);
#         }#T_8c0a3392_00e7_11ec_9aaa_b352c449eab1row17_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 5.0%, transparent 5.0%);
#         }#T_8c0a3392_00e7_11ec_9aaa_b352c449eab1row17_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 68.1%, transparent 68.1%);
#         }#T_8c0a3392_00e7_11ec_9aaa_b352c449eab1row18_col1{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 3.2%, transparent 3.2%);
#         }#T_8c0a3392_00e7_11ec_9aaa_b352c449eab1row18_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 61.0%, transparent 61.0%);
#         }#T_8c0a3392_00e7_11ec_9aaa_b352c449eab1row19_col2{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 50.2%, transparent 50.2%);
#         }</style><table id="T_8c0a3392_00e7_11ec_9aaa_b352c449eab1" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >City</th>        <th class="col_heading level0 col1" >Sales</th>        <th class="col_heading level0 col2" >Profit</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_8c0a3392_00e7_11ec_9aaa_b352c449eab1level0_row0" class="row_heading level0 row0" >511</th>
#                         <td id="T_8c0a3392_00e7_11ec_9aaa_b352c449eab1row0_col0" class="data row0 col0" >New Brunswick</

# %% [markdown]
# ## **6.5- Top words in City feature**

# %%
text = ' '.join(store_data['City'].str.lower())

wordcloud = WordCloud(width = 2000, height = 900, 
                      background_color ='black',
                      collocations=False,
                      max_words=5000,
                      min_font_size = 15).generate(text)
    
plt.figure(figsize=(12, 8), facecolor = 'k', edgecolor = 'k' )
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0) 
plt.show()

# %% [markdown]
# ## **6.6- Top words in Sub-Category**

# %%
text = ' '.join(store_data['Sub-Category'].str.lower())

wordcloud = WordCloud(width = 2000, height = 900, 
                      background_color ='black',
                      collocations=False,
                      max_words=5000,
                      min_font_size = 15).generate(text)
    
plt.figure(figsize=(12, 8), facecolor = 'k', edgecolor = 'k' )
plt.imshow(wordcloud)
plt.axis("off")
plt.tight_layout(pad = 0) 
plt.show()
